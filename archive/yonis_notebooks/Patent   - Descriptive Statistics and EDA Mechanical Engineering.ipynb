# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\moshi\Patent_Applicants_Gender_Classifier\data\clean_data_with_enrich.csv',dtype={'filing_year':'str'})
# Out:
# C:\Users\moshi\AppData\Local\Temp\ipykernel_30396\1178937112.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\moshi\Patent_Applicants_Gender_Classifier\data\clean_data_with_enrich.csv',dtype={'filing_year':'str'})

# %%
df = df[df['Parent_Catgeory'].isin(["Mech_Engr", "Trans"])]

# %%
pd.set_option('display.max_columns', None)

# %%
#how many records
df.shape
# Out:
# (130678, 37)

# %%
df.describe(include='all')
# Out:
#         application_number  uspc_class    one_if_male  one_if_female  \
# count         1.306780e+05    130678.0  130678.000000  130678.000000
# unique                 NaN       628.0            NaN            NaN
# top                    NaN       705.0            NaN            NaN
# freq                   NaN     11219.0            NaN            NaN
# mean          1.526437e+07         NaN       0.882459       0.117541
# std           9.470843e+05         NaN       0.322065       0.322065
# min           1.305488e+07         NaN       0.000000       0.000000
# 25%           1.447977e+07         NaN       1.000000       0.000000
# 50%           1.521064e+07         NaN       1.000000       0.000000
# 75%           1.602849e+07         NaN       1.000000       0.000000
# max           1.725752e+07         NaN       1.000000       1.000000
#
#        filing_year  one_if_patented  one_if_abandoned  one_if_pending  \
# count       130678    130678.000000     130678.000000   130678.000000
# unique           8              NaN               NaN             NaN
# top           2014              NaN               NaN             NaN
# freq         19034              NaN               NaN             NaN
# mean           NaN         0.576424          0.325005        0.098571
# std            NaN         0.494127          0.468379        0.298086
# min            NaN         0.000000          0.000000        0.000000
# 25%            NaN         0.000000          0.000000        0.000000
# 50%            NaN         1.000000          0.000000        0.000000
# 75%            NaN         1.000000          1.000000        0.000000
# max            NaN         1.000000          1.000000        1.000000
#
#          one_if_small  Biotechnology  Chem_Material_Engr  Comp_Archit  \
# count   130678.000000       130678.0            130678.0     130678.0
# unique            NaN            NaN                 NaN          NaN
# top               NaN            NaN                 NaN          NaN
# freq              NaN            NaN                 NaN          NaN
# mean         0.683198            0.0                 0.0          0.0
# std          0.465231            0.0                 0.0          0.0
# min          0.000000            0.0                 0.0          0.0
# 25%          0.000000            0.0                 0.0          0.0
# 50%          1.000000            0.0                 0.0          0.0
# 75%          1.000000            0.0                 0.0          0.0
# max          1.000000            0.0                 0.0          0.0
#
#         Comp_Net     Comms     Semis          Trans      Mech_Engr  \
# count   130678.0  130678.0  130678.0  130678.000000  130678.000000
# unique       NaN       NaN       NaN            NaN            NaN
# top          NaN       NaN       NaN            NaN            NaN
# freq         NaN       NaN       NaN            NaN            NaN
# mean         0.0       0.0       0.0       0.508448       0.491552
# std          0.0       0.0       0.0       0.499931       0.499931
# min          0.0       0.0       0.0       0.000000       0.000000
# 25%          0.0       0.0       0.0       0.000000       0.000000
# 50%          0.0       0.0       0.0       1.000000       0.000000
# 75%          0.0       0.0       0.0       1.000000       1.000000
# max          0.0       0.0       0.0       1.000000       1.000000
#
#                                                  abstract  \
# count                                              130678
# unique                                             130678
# top     Technologies are generally described for contr...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                            clean_abstract        kinkade  \
# count                                              130678  130678.000000
# unique                                             130640            NaN
# top     fastener retainer may include surface hook int...            NaN
# freq                                                    2            NaN
# mean                                                  NaN      16.942824
# std                                                   NaN      10.209617
# min                                                   NaN      -9.428000
# 25%                                                   NaN      11.256168
# 50%                                                   NaN      14.210000
# 75%                                                   NaN      18.612973
# max                                                   NaN     257.352769
#
#            word_count     char_count  median_word_length  avg_word_length  \
# count   130678.000000  130678.000000       130678.000000    130678.000000
# unique            NaN            NaN                 NaN              NaN
# top               NaN            NaN                 NaN              NaN
# freq              NaN            NaN                 NaN              NaN
# mean       109.880033     549.052656            4.680991         5.123508
# std         40.003705     201.148110            0.795077         0.485434
# min          3.000000      14.000000            2.000000         2.898734
# 25%         81.000000     404.000000            4.000000         4.791737
# 50%        113.000000     559.000000            5.000000         5.079596
# 75%        142.000000     692.000000            5.000000         5.408451
# max       1336.000000    6757.000000           10.000000        11.916667
#
#         skew_word_length  characters_per_word  syll_per_word  \
# count      130678.000000        130678.000000  130678.000000
# unique               NaN                  NaN            NaN
# top                  NaN                  NaN            NaN
# freq                 NaN                  NaN            NaN
# mean            0.587846             5.020074       1.624061
# std             0.338090             0.451659       0.198361
# min            -1.162434             2.488000       0.000000
# 25%             0.373504             4.707981       1.485915
# 50%             0.555208             4.984127       1.609272
# 75%             0.759390             5.291925       1.746032
# max             6.369237             8.333333       3.083333
#
#         words_per_sentence  sentences_per_paragraph  type_token_ratio  \
# count        130678.000000            130678.000000     130678.000000
# unique                 NaN                      NaN               NaN
# top                    NaN                      NaN               NaN
# freq                   NaN                      NaN               NaN
# mean             34.279248                 4.066369          0.523199
# std              25.288705                 2.105411          0.129532
# min               3.000000                 1.000000          0.050497
# 25%              21.000000                 2.000000          0.429530
# 50%              26.400000                 4.000000          0.507937
# 75%              36.500000                 5.000000          0.601102
# max             650.000000                48.000000          1.000000
#
#             syllables      sentences     long_words  complex_words  \
# count   130678.000000  130678.000000  130678.000000  130678.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean       177.046090       4.066369      33.723381      22.259187
# std         65.219738       2.105411      14.086684      10.617678
# min          0.000000       1.000000       0.000000       0.000000
# 25%        130.000000       2.000000      24.000000      15.000000
# 50%        179.000000       4.000000      33.000000      21.000000
# 75%        222.000000       5.000000      43.000000      29.000000
# max       2128.000000      48.000000     424.000000     296.000000
#
#        Gender_Target Patent_Target Parent_Catgeory
# count         130678        130678          130678
# unique             2             3               2
# top             Male      patented           Trans
# freq          115318         75326           66443
# mean             NaN           NaN             NaN
# std              NaN           NaN             NaN
# min              NaN           NaN             NaN
# 25%              NaN           NaN             NaN
# 50%              NaN           NaN             NaN
# 75%              NaN           NaN             NaN
# max              NaN           NaN             NaN

# %%
df.head()
# Out:
#     application_number uspc_class  one_if_male  one_if_female filing_year  \
# 0             13054882        701            1              0        2013
# 6             13261566        215            1              0        2013
# 8             13261588         29            1              0        2013
# 9             13261593        227            1              0        2013
# 12            13261630        219            1              0        2013
#
#     one_if_patented  one_if_abandoned  one_if_pending  one_if_small  \
# 0                 1                 0               0             0
# 6                 0                 1               0             1
# 8                 1                 0               0             1
# 9                 0                 1               0             1
# 12                1                 0               0             1
#
#     Biotechnology  Chem_Material_Engr  Comp_Archit  Comp_Net  Comms  Semis  \
# 0               0                   0            0         0      0      0
# 6               0                   0            0         0      0      0
# 8               0                   0            0         0      0      0
# 9               0                   0            0         0      0      0
# 12              0                   0            0         0      0      0
#
#     Trans  Mech_Engr                                           abstract  \
# 0       1          0  Technologies are generally described for contr...
# 6       0          1  The present invention relates to a bottle cap ...
# 8       0          1  These fixtures aid in installing sealing and s...
# 9       0          1  A stapling and cutting system for use by a phy...
# 12      0          1  Machinery and process are disclosed for laser ...
#
#                                        clean_abstract    kinkade  word_count  \
# 0   technology generally described controlling fli...  14.848509       109.0
# 6   present invention relates bottle cap comprisin...  59.112432       148.0
# 8   fixture aid installing sealing securing pipe s...  18.688077        65.0
# 9   stapling cutting system use physician cutting ...  11.390360       191.0
# 12  machinery process disclosed laser welding beam...  12.120303       132.0
#
#     char_count  median_word_length  avg_word_length  skew_word_length  \
# 0        542.0                 4.0         5.009174          0.534350
# 6        685.0                 4.0         4.662162          1.003380
# 8        370.0                 5.0         6.177419          2.994492
# 9        907.0                 4.0         4.790576          0.577245
# 12       694.0                 5.0         5.303030          0.685988
#
#     characters_per_word  syll_per_word  words_per_sentence  \
# 0              4.972477       1.678899              27.250
# 6              4.628378       1.439189             148.000
# 8              5.692308       1.830769              32.500
# 9              4.748691       1.497382              23.875
# 12             5.257576       1.621212              22.000
#
#     sentences_per_paragraph  type_token_ratio  syllables  sentences  \
# 0                       4.0          0.504587      183.0        4.0
# 6                       1.0          0.466216      213.0        1.0
# 8                       2.0          0.846154      119.0        2.0
# 9                       8.0          0.429319      286.0        8.0
# 12                      6.0          0.568182      214.0        6.0
#
#     long_words  complex_words Gender_Target Patent_Target Parent_Catgeory
# 0         35.0           28.0          Male      patented           Trans
# 6         39.0           26.0          Male     abandoned       Mech_Engr
# 8         23.0           14.0          Male      patented       Mech_Engr
# 9         51.0           28.0          Male     abandoned       Mech_Engr
# 12        39.0           27.0          Male      patented       Mech_Engr

# %%
#how many each year
all = sns.lineplot(data=df['filing_year'].value_counts(normalize=True).reset_index(),x='index',y='filing_year',label='All')
Male = sns.lineplot(data=df[df['Gender_Target']=='Male']['filing_year'].value_counts(normalize=True).reset_index(),x='index',y='filing_year',label='Male')
Female = sns.lineplot(data=df[df['Gender_Target']=='Female']['filing_year'].value_counts(normalize=True).reset_index(),x='index',y='filing_year',label='Female')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Percetage')
plt.title('Abstract Amount Trend')
plt.show()

# %%
#how many in each category
plt.figure(figsize=(15,5))
countplot=sns.barplot(df['Parent_Catgeory'].value_counts(normalize=True).reset_index(),x='index',y='Parent_Catgeory')
for i in countplot.containers:
    countplot.bar_label(i,)
plt.xlabel('Category')
plt.ylabel('Percentage')
plt.title('Category Distribution')
plt.show()
# Out:
# C:\Users\moshi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30396\3133342798.py in <module>
#       1 #how many in each category
#       2 plt.figure(figsize=(15,5))
# ----> 3 countplot=sns.barplot(df['Parent_Catgeory'].value_counts(normalize=True).reset_index(),x='index',y='Parent_Catgeory')
#       4 for i in countplot.containers:
#       5     countplot.bar_label(i,)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Parent_Catgeory'

# %%
#male vs female
gender_distribution = df.groupby('Parent_Catgeory')['Gender_Target'].value_counts(normalize=True)

print(gender_distribution)
# Out:
# Parent_Catgeory  Gender_Target
# Mech_Engr        Male             0.863501
#                  Female           0.136499
# Trans            Male             0.900787
#                  Female           0.099213
# Name: Gender_Target, dtype: float64

# %%
countplot=sns.barplot(df['Gender_Target'].value_counts(normalize=True).reset_index(),x='index',y='Gender_Target')
plt.title('Male Vs Female')
for p in countplot.patches:
    countplot.annotate(f'{str(round(p.get_height()*100,3))+"%"}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.ylabel('Percentage')
plt.show()
# Out:
# C:\Users\moshi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30396\1380850641.py in <module>
# ----> 1 countplot=sns.barplot(df['Gender_Target'].value_counts(normalize=True).reset_index(),x='index',y='Gender_Target')
#       2 plt.title('Male Vs Female')
#       3 for p in countplot.patches:
#       4     countplot.annotate(f'{str(round(p.get_height()*100,3))+"%"}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')
#       5
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Gender_Target'

# %%
cat_by_gender = df.groupby(['Gender_Target','Parent_Catgeory'])['application_number'].count().reset_index()
cat_by_gender['Percentage'] =  round(cat_by_gender['application_number']*100/ cat_by_gender.groupby('Gender_Target')['application_number'].transform('sum'),3)

# %%
cat_by_gender
# Out:
#   Gender_Target Parent_Catgeory  application_number  Percentage
# 0        Female       Mech_Engr                8768      57.083
# 1        Female           Trans                6592      42.917
# 2          Male       Mech_Engr               55467      48.099
# 3          Male           Trans               59851      51.901

# %%
plt.figure(figsize=(15,5))
countplot = sns.barplot(data=cat_by_gender, x='Parent_Catgeory', y='Percentage', hue='Gender_Target')
for i in countplot.containers:
    countplot.bar_label(i,)
plt.title('Category Distribution by Gender')
plt.xlabel('Parent_Catgeory')
plt.ylabel('Percentage')
plt.legend(title='Status')
plt.show()

# %%
#texr char per gender
text_char_df_gender =  df[['kinkade','word_count','char_count','median_word_length','avg_word_length','skew_word_length','characters_per_word','syll_per_word','words_per_sentence',
                    'sentences_per_paragraph','type_token_ratio','syllables','sentences','long_words','complex_words']]

# %%
normalized_df = (text_char_df_gender - text_char_df_gender.mean())/text_char_df_gender.std()

# %%
normalized_df = pd.concat([normalized_df,df['Gender_Target']], axis = 1)

# %%
normalized_df_melt = pd.melt(normalized_df, id_vars='Gender_Target', var_name='features', value_name='value')

# %%
plt.figure(figsize=(20,7))
sns.violinplot(data=normalized_df_melt, x = 'features', y='value', hue = 'Gender_Target',split=True)
plt.xticks(rotation=45)
plt.show()

# %%
#texr char per patnede staus
df = df[(df['one_if_small']==1) & (df['Patent_Target']!='pending')]

# %%
df['Patent_Target'].value_counts(normalize=True)
# Out:
# patented     0.59526
# abandoned    0.40474
# Name: Patent_Target, dtype: float64

# %%
text_char_df_gender =  df[['type_token_ratio',
'skew_word_length',
'syll_per_word',
'avg_word_length',
'char_count',
'characters_per_word',
'kinkade']]

normalized_df = (text_char_df_gender - text_char_df_gender.mean())/text_char_df_gender.std()

normalized_df = pd.concat([normalized_df,df['Patent_Target']], axis = 1)
normalized_df_melt = pd.melt(normalized_df, id_vars='Patent_Target', var_name='features', value_name='value')
plt.figure(figsize=(20,7))
sns.boxplot(data=normalized_df_melt, x = 'features', y='value', hue = 'Patent_Target')
plt.title('Distribution of most important features for each Class')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='Patent_Target', y='skew_word_length', data=df)
plt.xlabel('Class')
plt.ylabel('Feature')
plt.title('Distribution of TTR by Class')
plt.show()

# %%
sns.boxplot(x='Patent_Target', y='kinkade', data=df)
plt.xlabel('Class')
plt.ylabel('Feature')
plt.title('Distribution of Kinkade by Class')
plt.show()

# %%
#patent status

countplot=sns.barplot(df['Patent_Target'].value_counts(normalize=True).reset_index(),x='index',y='Patent_Target')
for p in countplot.patches:
    countplot.annotate(f'{str(round(p.get_height()*100,3))+"%"}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.title('Patent Status Distribution')
plt.xlabel('Patent Status')
plt.ylabel('Percentage')
plt.show()

# %%
#patent status

countplot=sns.barplot(df[df['one_if_small']==1]['Patent_Target'].value_counts(normalize=True).reset_index(),x='index',y='Patent_Target')
for p in countplot.patches:
    countplot.annotate(f'{str(round(p.get_height()*100,3))+"%"}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.title('Small Entity Patent Status Distribution')
plt.xlabel('Patent Status')
plt.ylabel('Percentage')
plt.show()

# %%
status_by_gender = df.groupby(['Gender_Target','Patent_Target'])['application_number'].count().reset_index()
status_by_gender['Percentage'] =  round(status_by_gender['application_number']*100/ status_by_gender.groupby('Gender_Target')['application_number'].transform('sum'),3)

# %%
countplot = sns.barplot(data=status_by_gender, x='Gender_Target', y='Percentage', hue='Patent_Target')
for i in countplot.containers:
    countplot.bar_label(i,)
plt.title('Patent Status Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Percentage')
plt.legend(title='Status')
plt.show()

# %%
#female and reject rate per category
cat_reject_rate = df.groupby(['Parent_Catgeory','Gender_Target','Patent_Target','one_if_small'])['application_number'].count().reset_index()

# %%
cat_reject_rate['how_many'] = cat_reject_rate.groupby(['Parent_Catgeory','Gender_Target'])['application_number'].transform('sum')

# %%
all_reject_rate = cat_reject_rate[cat_reject_rate['Patent_Target']=='abandoned']

# %%
all_reject_rate['all_reject'] = all_reject_rate.groupby(['Parent_Catgeory','Gender_Target'])['application_number'].transform('sum')
# Out:
# <ipython-input-42-d4cf703027aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_reject_rate['all_reject'] = all_reject_rate.groupby(['Parent_Catgeory','Gender_Target'])['application_number'].transform('sum')

# %%
all_reject_rate=all_reject_rate[['Parent_Catgeory','how_many','all_reject','Gender_Target']].drop_duplicates()

# %%
all_reject_rate['reject_rate'] = round(all_reject_rate['all_reject']/all_reject_rate['how_many'],2)

# %%
all_reject_rate
# Out:
#        Parent_Catgeory  how_many  all_reject Gender_Target  reject_rate
# 0        Biotechnology      2446         873        Female     0.356909
# 6        Biotechnology     12446        3710          Male     0.298088
# 12  Chem_Material_Engr      1880         700        Female     0.372340
# 18  Chem_Material_Engr     18535        5787          Male     0.312220
# 24               Comms      1885         488        Female     0.258886
# 30               Comms     19233        3727          Male     0.193782
# 36         Comp_Archit      1178         280        Female     0.237691
# 42         Comp_Archit     14444        3132          Male     0.216837
# 48            Comp_Net      1220         272        Female     0.222951
# 54            Comp_Net     16163        3088          Male     0.191054
# 60           Mech_Engr      8768        3885        Female     0.443089
# 66           Mech_Engr     55467       17438          Male     0.314385
# 72               Semis      2198         456        Female     0.207461
# 78               Semis     32972        5457          Male     0.165504
# 84               Trans      6592        2720        Female     0.412621
# 90               Trans     59851       18428          Male     0.307898

# %%
plt.figure(figsize=(15,7))
countplot = sns.barplot(data=all_reject_rate, x='Parent_Catgeory', y='reject_rate', hue='Gender_Target')
for i in countplot.containers:
    countplot.bar_label(i,)
plt.title('Reject Rate per Category and Gender')
plt.xlabel('Category')
plt.ylabel('Reject Rate')
plt.legend(title='Status')
plt.show()

# %%
cat_reject_rate['Reject_Rate'] = round(cat_reject_rate['application_number']/cat_reject_rate.groupby(['Parent_Catgeory','Gender_Target','one_if_small'])['application_number'].transform('sum'),2)

# %%
cat_reject_rate = cat_reject_rate[cat_reject_rate['Patent_Target']=='abandoned']

# %%
cat_reject_rate
# Out:
#        Parent_Catgeory Gender_Target Patent_Target  one_if_small  \
# 0        Biotechnology        Female     abandoned             0
# 1        Biotechnology        Female     abandoned             1
# 4        Biotechnology          Male     abandoned             0
# 5        Biotechnology          Male     abandoned             1
# 8   Chem_Material_Engr        Female     abandoned             0
# 9   Chem_Material_Engr        Female     abandoned             1
# 12  Chem_Material_Engr          Male     abandoned             0
# 13  Chem_Material_Engr          Male     abandoned             1
# 16               Comms        Female     abandoned             0
# 17               Comms        Female     abandoned             1
# 20               Comms          Male     abandoned             0
# 21               Comms          Male     abandoned             1
# 24         Comp_Archit        Female     abandoned             0
# 25         Comp_Archit        Female     abandoned             1
# 28         Comp_Archit          Male     abandoned             0
# 29         Comp_Archit          Male     abandoned             1
# 32            Comp_Net        Female     abandoned             0
# 33            Comp_Net        Female     abandoned             1
# 36            Comp_Net          Male     abandoned             0
# 37            Comp_Net          Male     abandoned             1
# 40           Mech_Engr        Female     abandoned             0
# 41           Mech_Engr        Female     abandoned             1
# 44           Mech_Engr          Male     abandoned             0
# 45           Mech_Engr          Male     abandoned             1
# 48               Semis        Female     abandoned             0
# 49               Semis        Female     abandoned             1
# 52               Semis          Male     abandoned             0
# 53               Semis          Male     abandoned             1
# 56               Trans        Female     abandoned             0
# 57               Trans        Female     abandoned             1
# 60               Trans          Male     abandoned             0
# 61               Trans          Male     abandoned             1
#
#     application_number  Reject_Rate
# 0                  191         0.27
# 1                  682         0.50
# 4                  842         0.17
# 5                 2868         0.48
# 8                  167         0.29
# 9                  533         0.51
# 12                2044         0.29
# 13                3743         0.42
# 16                 106         0.12
# 17                 382         0.43
# 20                1380         0.12
# 21                2347         0.33
# 24                 121         0.17
# 25                 159         0.50
# 28                1602         0.17
# 29                1530         0.45
# 32                 112         0.15
# 33                 160         0.48
# 36                1508         0.15
# 37                1580         0.37
# 40                 293         0.27
# 41                3592         0.54
# 44                3568         0.22
# 45               13870         0.41
# 48                 114         0.12
# 49                 342         0.30
# 52                1938         0.11
# 53                3519         0.26
# 56                 274         0.27
# 57                2446         0.50
# 60                3942         0.21
# 61               14486         0.40

# %%
catplot = sns.catplot(kind = 'bar', data=cat_reject_rate, x= 'Parent_Catgeory',y='Reject_Rate', col = 'one_if_small',hue='Gender_Target',legend=False, legend_out=False)
#countplot = sns.barplot(cat_reject_rate[cat_reject_rate['Patent_Target']=='abandoned'],x='Parent_Catgeory',y='Reject_Rate',hue='Gender_Target')
# Add label values to the plot
catplot.set_xticklabels(rotation=45)
#plt.tight_layout()

plt.legend(title='Gender', bbox_to_anchor=(1.02, 1), loc='upper left')
for ax in catplot.axes.flat:
    ax.tick_params(axis='x', labelsize=7)
    ax.tick_params(axis='y', labelsize=7)
    for p in ax.patches:
        height = p.get_height()
        ax.annotate(f'{height:.2f}', (p.get_x() + p.get_width() / 2., height), ha='center', va='center', xytext=(1, 6), textcoords='offset points',fontsize=7)
catplot.fig.suptitle('Reject Rate per Category and Gender',fontsize=10)
plt.subplots_adjust(top=0.9)

# %%
cat_reject_rate
# Out:
#        Parent_Catgeory Gender_Target Patent_Target  application_number  \
# 0        Biotechnology        Female     abandoned                 682
# 3        Biotechnology          Male     abandoned                2868
# 6   Chem_Material_Engr        Female     abandoned                 533
# 9   Chem_Material_Engr          Male     abandoned                3743
# 12               Comms        Female     abandoned                 382
# 15               Comms          Male     abandoned                2347
# 18         Comp_Archit        Female     abandoned                 159
# 21         Comp_Archit          Male     abandoned                1530
# 24            Comp_Net        Female     abandoned                 160
# 27            Comp_Net          Male     abandoned                1580
# 30           Mech_Engr        Female     abandoned                3592
# 33           Mech_Engr          Male     abandoned               13870
# 36               Semis        Female     abandoned                 342
# 39               Semis          Male     abandoned                3519
# 42               Trans        Female     abandoned                2446
# 45               Trans          Male     abandoned               14486
#
#     Reject_Rate  difference
# 0          0.42         NaN
# 3          0.40       -0.02
# 6          0.44         NaN
# 9          0.37       -0.07
# 12         0.40         NaN
# 15         0.31       -0.09
# 18         0.44         NaN
# 21         0.39       -0.05
# 24         0.42         NaN
# 27         0.34       -0.08
# 30         0.48         NaN
# 33         0.37       -0.11
# 36         0.28         NaN
# 39         0.25       -0.03
# 42         0.45         NaN
# 45         0.37       -0.08

# %%
from scipy.stats import mannwhitneyu

# %%
df.head()
# Out:
#    application_number uspc_class  one_if_male  one_if_female filing_year  \
# 0            13054882        701            1              0        2013
# 1            13260099        424            1              0        2013
# 2            13261421        424            1              0        2013
# 3            13261486        136            1              0        2013
# 4            13261494        362            1              0        2013
#
#    one_if_patented  one_if_abandoned  one_if_pending  one_if_small  \
# 0                1                 0               0             0
# 1                0                 1               0             0
# 2                1                 0               0             1
# 3                1                 0               0             1
# 4                1                 0               0             1
#
#    Biotechnology  ...  words_per_sentence  sentences_per_paragraph  \
# 0              0  ...           27.250000                      4.0
# 1              1  ...           37.666667                      3.0
# 2              1  ...           19.000000                      2.0
# 3              0  ...           49.000000                      3.0
# 4              0  ...           45.666667                      3.0
#
#    type_token_ratio  syllables  sentences  long_words  complex_words  \
# 0          0.504587      183.0        4.0        35.0           28.0
# 1          0.530973      199.0        3.0        36.0           26.0
# 2          0.736842       77.0        2.0        21.0           16.0
# 3          0.653061      282.0        3.0        67.0           51.0
# 4          0.583942      200.0        3.0        39.0           25.0
#
#   Gender_Target Patent_Target     Parent_Catgeory
# 0          Male      patented               Trans
# 1          Male     abandoned       Biotechnology
# 2          Male      patented       Biotechnology
# 3          Male      patented  Chem_Material_Engr
# 4          Male      patented               Semis
#
# [5 rows x 37 columns]

# %%
accepted = df[df['Patent_Target'] == 'patented']['sentences_per_paragraph']
rejected = df[df['Patent_Target'] == 'abandoned']['sentences_per_paragraph']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='Patent_Target', y='type_token_ratio', data=df[(df['one_if_small']==0) & (df['Parent_Catgeory']=='Mech_Engr') ])
plt.xlabel('Application Outcome')
plt.ylabel('Median Number of Words')
plt.title('Relationship between Median Words and Application Outcome')
plt.show()
